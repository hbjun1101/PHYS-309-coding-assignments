# %%
import numpy as np
import matplotlib.pyplot as plt

 # Contains physical constants defined in SI units (default) as well as other systems
from scipy import constants

# Make easily readable plots with large axis labels
plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

c        = constants.c
epsilon0 = constants.epsilon_0
mu0      = constants.mu_0
q_e      = constants.e           

#  Problem 1

r_min = 1e-10
r_max = 1e-2
num_r = 200

r_vals = np.logspace(np.log10(r_min), np.log10(r_max), num_r)
E_vals = E_field(r_vals, q_e, epsilon0)

plt.figure(figsize=(8,6))
plt.plot(r_vals, E_vals, label="E'(r') in K' (original eps0)")
plt.xscale("log")
plt.yscale("log")
plt.xlabel(r"$r' \, (\mathrm{m})$")
plt.ylabel(r"$E'(r') \, (\mathrm{N/C})$")
plt.title("Problem 1")
plt.grid(True)
plt.legend()
plt.show()

# Problem 2

f_array = np.linspace(0, 0.99, 200)
c_prime_vals = c_prime(f_array)

plt.figure(figsize=(8,6))
plt.plot(f_array, c_prime_vals)
plt.xlabel("f (dimensionless)")
plt.ylabel(r"$c'(f)$ [m/s]")
plt.title("Problem 2")
plt.grid(True)
plt.show()

#  Problem 3

r_test = 1e-6  
eps0_prime_vals = 1.0/( mu0 * c_prime_vals**2 )
E_prime_vals = E_field(r_test, q_e, eps0_prime_vals)

fig, (ax1, ax2) = plt.subplots(2,1, figsize=(7,10), sharex=True)

ax1.plot(f_array, eps0_prime_vals)
ax1.set_ylabel(r"$\varepsilon_0'(f)$ [F/m]")
ax1.set_title("Problem 3")

ax2.plot(f_array, E_prime_vals, color='r')
ax2.set_xlabel("f (dimensionless)")
ax2.set_ylabel(r"$E'(r'=10^{-6}\mathrm{m})$ [N/C]")

plt.tight_layout()
plt.show()

#  Problem 4

f_fixed = 0.5
E_orig_r = E_field(r_vals, q_e, epsilon0)
eps0_prime_05 = 1.0/( mu0 * c_prime(f_fixed)**2 )
E_mod_r       = E_field(r_vals, q_e, eps0_prime_05)

plt.figure(figsize=(8,6))
plt.plot(r_vals, E_orig_r, label="Original E'(r') w/ eps0")
plt.plot(r_vals, E_mod_r, label=f"Modified E'(r') w/ eps0'(f={f_fixed})")
plt.xscale("log")
plt.yscale("log")
plt.xlabel(r"$r' (\mathrm{m})$")
plt.ylabel(r"$E'(r') \, (\mathrm{N/C})$")
plt.title("Problem 4")
plt.grid(True)
plt.legend()
plt.show()

#  Problem 5

I = 1.0
R = 1.0

mu0_prime_array = 1.0/( epsilon0 * c_prime_vals**2 )
B_prime_array   = (mu0_prime_array * I)/(2*R)

fig, (ax1, ax2) = plt.subplots(2,1, figsize=(7,10), sharex=True)

ax1.plot(f_array, mu0_prime_array)
ax1.set_ylabel(r"$\mu_0'(f)$ [N/A$^2$]")
ax1.set_title("Problem 5)")

ax2.plot(f_array, B_prime_array, color='r')
ax2.set_xlabel("f (dimensionless)")
ax2.set_ylabel("B'(f) [Tesla]")

plt.tight_layout()
plt.show()

#  Problem 6

E_in_K  = E_field(r_test, q_e, epsilon0)
B_in_K  = mu0*I/(2*R)

def ratio_minus1(a, b):
    """ returns a/b - 1 (dimensionless).  If 0 => a= b exactly """
    return a/b - 1

f_long = np.linspace(0, 0.99, 300)
E_ratio_vals = []
B_ratio_vals = []

for ff in f_long:
    eps0p = 1.0/( mu0*( c_prime(ff) )**2 )
    Eprime_val = E_field(r_test, q_e, eps0p)
    mu0p = 1.0/( epsilon0*( c_prime(ff) )**2 )
    Bprime_val = mu0p*I/(2*R)
    
    E_ratio_vals.append( ratio_minus1(Eprime_val, E_in_K) )
    B_ratio_vals.append( ratio_minus1(Bprime_val, B_in_K) )

E_ratio_vals = np.array(E_ratio_vals)
B_ratio_vals = np.array(B_ratio_vals)

plt.figure(figsize=(8,6))
plt.plot(f_long, E_ratio_vals, label="(E'(f)/E) - 1")
plt.plot(f_long, B_ratio_vals, label="(B'(f)/B) - 1")
plt.axhline(0, color='k', linestyle='--')
plt.xlabel("f (dimensionless)")
plt.ylabel("Ratio - 1")
plt.title("Problem 6")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...
